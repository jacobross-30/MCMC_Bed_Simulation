# %% [markdown]
# # Tutorial 4: Initializing a small-scale chain

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import Topography
import MCMC
import gstatsim as gs
from sklearn.preprocessing import QuantileTransformer
import skgstat as skg

# %%
# load compiled bed elevation measurements
df = pd.read_csv('NinnisDataGridded_update.csv')

# %%
# create a grid of x and y coordinates
x_uniq = np.unique(df.x)
y_uniq = np.unique(df.y)

xmin = np.min(x_uniq)
xmax = np.max(x_uniq)
ymin = np.min(y_uniq)
ymax = np.max(y_uniq)

cols = len(x_uniq)
rows = len(y_uniq)

resolution = 500

xx, yy = np.meshgrid(x_uniq, y_uniq)

# %%
# load other data
dhdt = df['dhdt'].values.reshape(xx.shape)
smb = df['smb'].values.reshape(xx.shape)
velx = df['velx'].values.reshape(xx.shape)
vely = df['vely'].values.reshape(xx.shape)
bedmap_mask = df['bedmap_mask'].values.reshape(xx.shape)
bedmachine_thickness = df['bedmachine_thickness'].values.reshape(xx.shape)
bedmap_surf = df['bedmap_surf'].values.reshape(xx.shape)
highvel_mask = df['highvel_mask'].values.reshape(xx.shape)
bedmachine_bed = df['bedmap_surf'].values.reshape(xx.shape) - bedmachine_thickness
bedmap_bed = df['bedmap_bed'].values.reshape(xx.shape)

# %%
# create conditioning data
# bed elevation measurement in grounded ice region, and bedmap topography elsewhere
cond_bed = np.where(bedmap_mask == 1, df['bed'].values.reshape(xx.shape), bedmap_bed)
df['cond_bed'] = cond_bed.flatten()
# create a mask of conditioning data
data_mask = ~np.isnan(cond_bed)

# %% [markdown]
# __step1: calculate the trend__

# %%
initial_bed = np.loadtxt('Ninnis_bed_1000000.txt')
#initial_bed = np.loadtxt('sgs_bed.txt')

# %%
import scipy as sp
trend = sp.ndimage.gaussian_filter(initial_bed, sigma=10)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4),gridspec_kw={'width_ratios': [1, 1.3]} )

axes[0].pcolormesh(xx, yy, initial_bed, vmax=1500,vmin=-3500)
axes[0].set_title('initial bed')
axes[0].set_aspect('equal')

bedfig = axes[1].pcolormesh(xx, yy, trend, vmax=1500,vmin=-3500)
axes[1].set_title('topography trend (smoothed initial bed)')
axes[1].set_aspect('equal')
fig.colorbar(bedfig, ax=axes[1])

# %% [markdown]
# __step2: calculate detrended variogram__

# %%
###################WHEN NO DETREND###################
#normalize the conditioning bed data, saved to df['Nbed']
data = df['cond_bed'].values.reshape(-1,1)
nst_trans = QuantileTransformer(n_quantiles=500, output_distribution="normal",random_state=0).fit(data)
transformed_data = nst_trans.transform(data)
df['Nbed'] = transformed_data

# %%
# normalize the de-trended conditioning data, saved to df['Nbed_residual']
#df['cond_bed_residual']=df['cond_bed'].values-trend.flatten()
#data = df['cond_bed_residual'].values.reshape(-1,1)
#nst_trans = QuantileTransformer(n_quantiles=500, output_distribution="normal",random_state=0).fit(data)
#transformed_data = nst_trans.transform(data)
#df['Nbed_residual'] = transformed_data

# %%
###################WHEN NO DETREND###################
df_sampled = df.sample(frac=0.4, random_state=42)
df_sampled = df_sampled[df_sampled["cond_bed"].isnull() == False]
df_sampled = df_sampled[df_sampled["bedmap_mask"]==1]
coords = df_sampled[['x','y']].values
values = df_sampled['Nbed']

# randomly drop out 50% of coordinates. Decrease this value if you have a lot of data and it takes a long time to run
#df_sampled = df.sample(frac=0.4, random_state=42)
#df_sampled = df_sampled[df_sampled["cond_bed_residual"].isnull() == False]
#df_sampled = df_sampled[df_sampled["bedmap_mask"]==1]
#df_sampled = df_sampled[df_sampled["highvel_mask"]==1]

# compute experimental (isotropic) variogram
#coords = df_sampled[['x','y']].values
#values = df_sampled['Nbed_residual']

maxlag = 20000      # maximum range distance
n_lags = 70         # num of bins (try decreasing if this is taking too long)

# compute variogram
V1 = skg.Variogram(coords, values, bin_func='even', n_lags=n_lags, maxlag=maxlag, normalize=False, model='matern')

# extract variogram values
xdata = V1.bins
ydata = V1.experimental

V1_p = V1.parameters

# evaluate models
xi = np.linspace(0, xdata[-1], n_lags) 
y_mtn = [skg.models.matern(h, V1_p[0], V1_p[1], V1_p[2], V1_p[3]) for h in xi]
# variogram parameter is [range, sill, shape, nugget] for matern model.

plt.figure(figsize=(6,4))
plt.scatter(xdata, ydata, s=12, c='g')
plt.plot(xi, y_mtn,'b-.', label='Matern variogram model')
plt.title('Isotropic Experimental Variogram')
plt.xlabel('Lag (m)'); plt.ylabel('Semivariance')
plt.show()

# %%
V1_p
# Out:
# [19999.99999999977, 0.41376614234164394, 0.7415215774724424, 0]

# %%
###################WHEN NO DETREND###################
# load the initial bed, make sure no bed in grounded ice region is higher altitude than ice surface
initial_bed = np.loadtxt('Ninnis_bed_1000000.txt')
thickness = bedmap_surf - initial_bed
initial_bed = np.where((thickness<=0)&(bedmap_mask==1), bedmap_surf-1, initial_bed)

# %% [markdown]
# ### Then initiating the SGS chain

# %% [markdown]
# The first 4 initialization process are very similar to chain_crf, please refers to Tutorial 3 for detailed information

# %%
grounded_ice_mask = (bedmap_mask == 1)

# %% [markdown]
# step3: set up the chain
# - change initial bed
# - set normal transformation
# - set trend

# %%
###################WHEN NO DETREND###################
smallScaleChain = MCMC.chain_sgs(xx, yy, initial_bed, bedmap_surf, velx, vely, dhdt, smb, cond_bed, data_mask, grounded_ice_mask, resolution)
# Out:
# before running the chain, please set where the block update will be using the object's function set_update_in_region(region_mask) and set_update_region(update_in_region)
# please also set up the sgs parameters using set_sgs_param(self, block_size, sgs_param)
# then please set up the loss function using either set_loss_type or set_loss_func

# %%
#smallScaleChain = MCMC.chain_sgs(xx, yy, initial_bed, bedmap_surf, velx, vely, dhdt, smb, cond_bed, data_mask, grounded_ice_mask, resolution)

# %%
smallScaleChain.set_update_region(True,highvel_mask)
# Out:
# the update blocks is set to be randomly generated for any locations inside the given region

# %%
smallScaleChain.set_loss_type(map_func='sumsquare', sigma_mc=4, massConvInRegion=True)

# %%
# set up the block sizes
min_block_x = 5
max_block_x = 20
min_block_y = 5
max_block_y = 20
smallScaleChain.set_block_sizes(min_block_x, max_block_x, min_block_y, max_block_y)

# %% [markdown]
# Sequential Gaussian Simulation is set to perform on the normalized data. This nst_trans is an object of the QuantileTranformer class in scikit-learn python library. The *fit_variogram* function returns a nst_trans object, which could be directly used here

# %%
###################WHEN NO DETREND###################
smallScaleChain.set_normal_transformation(nst_trans, do_transform=False)

# %%
#smallScaleChain.set_normal_transformation(nst_trans, do_transform=True)

# %% [markdown]
# When running the SGS chain, it is possible to 'detrend' the topography.
#
# Detrend topography refers to substracting a pre-defined trend from the topography map, where the trend suppose to represent long-wavelength features that violate stationary properties of SGS. If choose to detrend the topography, the argument *detrend_map* need to be set to True, and the argument *trend* need to be a 2D numpy array representing the topography trend

# %%
###################WHEN NO DETREND###################
smallScaleChain.set_trend(trend = [], detrend_map = False)

# %%
#smallScaleChain.set_trend(trend = trend, detrend_map = True)

# %%
smallScaleChain.set_variogram('Matern',V1_p[0],V1_p[1],0,isotropic=True,vario_smoothness=V1_p[2])
# Out:
# the variogram is set to type Matern

# %%
smallScaleChain.set_sgs_param(48, 50e3, sgs_rand_dropout_on=False)
# Out:
# because the sgs_rand_dropout_on is set to False, the dropout_rate is automatically set to 0

# %% [markdown]
# __step4: run the chain, check if the loss is correct__

# %%
beds = np.loadtxt('Ninnis_SmallScale_bed_0.txt')
largeScaleChain.initial_bed = beds

# %%
#seed = 23034902
#randomGenerator = np.random.default_rng(seed)

#beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = smallScaleChain.run(n_iter=100, rng_seed=randomGenerator, only_save_last_bed=False, info_per_iter = 1000)

# %%
n_iter = 5000

seed = 23034902
randomGenerator = np.random.default_rng(seed)

for i in range(0,11):
    beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used  = smallScaleChain.run_newsgs(n_iter=n_iter, rng_seed=randomGenerator, only_save_last_bed=True, info_per_iter = 1000)
    # save all the data in every run of the algorithm
    np.savetxt('Ninnis_SmallScale_loss_'+str(i*n_iter)+'.txt', loss)
    np.savetxt('Ninnis_SmallScale_steps_'+str(i*n_iter)+'.txt', steps) 
    np.savetxt('Ninnis_SmallScale_bed_'+str(i*n_iter)+'.txt',beds)
    # set up the next chain
    smallScaleChain.initial_bed = beds
# Out:
# i: 0 mc loss: 8.252e+04 loss: 8.252e+04 acceptance rate: 1.0
# i: 1000 mc loss: 8.112e+04 loss: 8.112e+04 acceptance rate: 0.2977022977022977
# i: 2000 mc loss: 8.044e+04 loss: 8.044e+04 acceptance rate: 0.2748625687156422
# i: 3000 mc loss: 8.003e+04 loss: 8.003e+04 acceptance rate: 0.26024658447184273
# i: 4000 mc loss: 7.977e+04 loss: 7.977e+04 acceptance rate: 0.2466883279180205
# i: 0 mc loss: 7.953e+04 loss: 7.953e+04 acceptance rate: 0.0
# i: 1000 mc loss: 7.934e+04 loss: 7.934e+04 acceptance rate: 0.23676323676323677
# i: 2000 mc loss: 7.922e+04 loss: 7.922e+04 acceptance rate: 0.23338330834582707
# i: 3000 mc loss: 7.908e+04 loss: 7.908e+04 acceptance rate: 0.22925691436187937
# i: 4000 mc loss: 7.900e+04 loss: 7.900e+04 acceptance rate: 0.2271932016995751
# i: 0 mc loss: 7.886e+04 loss: 7.886e+04 acceptance rate: 1.0
# i: 1000 mc loss: 7.883e+04 loss: 7.883e+04 acceptance rate: 0.21878121878121878
# i: 2000 mc loss: 7.879e+04 loss: 7.879e+04 acceptance rate: 0.21039480259870064
# i: 3000 mc loss: 7.879e+04 loss: 7.879e+04 acceptance rate: 0.21826057980673108
# i: 4000 mc loss: 7.877e+04 loss: 7.877e+04 acceptance rate: 0.22419395151212196
# i: 0 mc loss: 7.876e+04 loss: 7.876e+04 acceptance rate: 0.0
# i: 1000 mc loss: 7.873e+04 loss: 7.873e+04 acceptance rate: 0.22777222777222778
# i: 2000 mc loss: 7.871e+04 loss: 7.871e+04 acceptance rate: 0.22938530734632684
# i: 3000 mc loss: 7.871e+04 loss: 7.871e+04 acceptance rate: 0.22725758080639788
# i: 4000 mc loss: 7.871e+04 loss: 7.871e+04 acceptance rate: 0.23044238940264933
# i: 0 mc loss: 7.872e+04 loss: 7.872e+04 acceptance rate: 1.0
# i: 1000 mc loss: 7.874e+04 loss: 7.874e+04 acceptance rate: 0.24175824175824176
# i: 2000 mc loss: 7.872e+04 loss: 7.872e+04 acceptance rate: 0.23388305847076463
# i: 3000 mc loss: 7.874e+04 loss: 7.874e+04 acceptance rate: 0.2355881372875708
# i: 4000 mc loss: 7.875e+04 loss: 7.875e+04 acceptance rate: 0.23144213946513373
# i: 0 mc loss: 7.877e+04 loss: 7.877e+04 acceptance rate: 0.0
# i: 1000 mc loss: 7.878e+04 loss: 7.878e+04 acceptance rate: 0.24475524475524477
# i: 2000 mc loss: 7.879e+04 loss: 7.879e+04 acceptance rate: 0.26436781609195403
# i: 3000 mc loss: 7.882e+04 loss: 7.882e+04 acceptance rate: 0.25458180606464514
# i: 4000 mc loss: 7.884e+04 loss: 7.884e+04 acceptance rate: 0.2509372656835791
# i: 0 mc loss: 7.888e+04 loss: 7.888e+04 acceptance rate: 0.0
# i: 1000 mc loss: 7.890e+04 loss: 7.890e+04 acceptance rate: 0.23776223776223776
# i: 2000 mc loss: 7.893e+04 loss: 7.893e+04 acceptance rate: 0.23588205897051473
# i: 3000 mc loss: 7.897e+04 loss: 7.897e+04 acceptance rate: 0.23792069310229924
# i: 4000 mc loss: 7.900e+04 loss: 7.900e+04 acceptance rate: 0.23944013996500874
# i: 0 mc loss: 7.902e+04 loss: 7.902e+04 acceptance rate: 1.0
# i: 1000 mc loss: 7.903e+04 loss: 7.903e+04 acceptance rate: 0.2727272727272727
# i: 2000 mc loss: 7.902e+04 loss: 7.902e+04 acceptance rate: 0.2613693153423288
# i: 3000 mc loss: 7.904e+04 loss: 7.904e+04 acceptance rate: 0.25558147284238586
# i: 4000 mc loss: 7.907e+04 loss: 7.907e+04 acceptance rate: 0.2604348912771807
# i: 0 mc loss: 7.908e+04 loss: 7.908e+04 acceptance rate: 0.0
# i: 1000 mc loss: 7.909e+04 loss: 7.909e+04 acceptance rate: 0.2677322677322677
# i: 2000 mc loss: 7.910e+04 loss: 7.910e+04 acceptance rate: 0.25787106446776614
# i: 3000 mc loss: 7.912e+04 loss: 7.912e+04 acceptance rate: 0.2595801399533489
# i: 4000 mc loss: 7.914e+04 loss: 7.914e+04 acceptance rate: 0.2621844538865284
# i: 0 mc loss: 7.918e+04 loss: 7.918e+04 acceptance rate: 0.0
# i: 1000 mc loss: 7.920e+04 loss: 7.920e+04 acceptance rate: 0.27972027972027974
# i: 2000 mc loss: 7.922e+04 loss: 7.922e+04 acceptance rate: 0.25737131434282856
# i: 3000 mc loss: 7.924e+04 loss: 7.924e+04 acceptance rate: 0.2659113628790403
# i: 4000 mc loss: 7.927e+04 loss: 7.927e+04 acceptance rate: 0.26493376655836043
# i: 0 mc loss: 7.930e+04 loss: 7.930e+04 acceptance rate: 1.0
# i: 1000 mc loss: 7.932e+04 loss: 7.932e+04 acceptance rate: 0.2967032967032967
# i: 2000 mc loss: 7.933e+04 loss: 7.933e+04 acceptance rate: 0.29035482258870565
# i: 3000 mc loss: 7.936e+04 loss: 7.936e+04 acceptance rate: 0.28490503165611464
# i: 4000 mc loss: 7.939e+04 loss: 7.939e+04 acceptance rate: 0.28192951762059487

# %%
beds.shape
# Out:
# (580, 399)

# %%
plt.pcolormesh(xx,yy,smallScaleChain.initial_bed,vmax=2000,vmin=-2500)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
plt.pcolormesh(xx,yy,beds,vmax=2000,vmin=-2500)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
plt.pcolormesh(xx,yy,beds-smallScaleChain.initial_bed, cmap='RdBu',vmax=200,vmin=-200)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
total_iter = 55000
n_per_file = 5000

loss = np.zeros(total_iter)
steps = np.zeros(total_iter)
for i in range(0,int(total_iter/n_per_file)):
    loss[i*n_per_file:(i+1)*n_per_file] = np.loadtxt('Ninnis_SmallScale_loss_' + str(i*n_per_file) + '.txt')
    steps[i*n_per_file:(i+1)*n_per_file] = np.loadtxt('Ninnis_SmallScale_steps_' + str(i*n_per_file) + '.txt')


acceptance_rate = [np.mean(steps[i:i+1000]) for i in range(total_iter - 1000)]

# %%
plt.plot(loss)
